# %%
import xarray as xr

data_directory = r"/oscar/home/pvankatw/data/pvankatw/CMIP/"
data_path = r"pr_day_MPI-ESM1-2-HR_ssp585_r1i1p1f1_gn_20150101-20191231.nc"
in_filename = data_directory + data_path
ds = xr.open_dataset(in_filename)
ds
# Out:
# <xarray.Dataset> Size: 539MB
# Dimensions:    (time: 1826, bnds: 2, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) datetime64[ns] 15kB 2015-01-01T12:00:00 ... 2019-12-31T...
#   * lat        (lat) float64 2kB -89.28 -88.36 -87.42 ... 87.42 88.36 89.28
#   * lon        (lon) float64 3kB 0.0 0.9375 1.875 2.812 ... 357.2 358.1 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] 29kB ...
#     lat_bnds   (lat, bnds) float64 3kB ...
#     lon_bnds   (lon, bnds) float64 6kB ...
#     pr         (time, lat, lon) float32 539MB ...
# Attributes: (12/47)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   60265.0
#     branch_time_in_parent:  60265.0
#     contact:                cmip6-mpi-esm@dkrz.de
#     ...                     ...
#     title:                  MPI-ESM1-2-HR output prepared for CMIP6
#     variable_id:            pr
#     variant_label:          r1i1p1f1
#     license:                CMIP6 model data produced by DKRZ is licensed und...
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/9093c676-cbb8-4c96-a25b-3a68ed8606f0

# %%
import pyremap

# %%
inDescriptor = pyremap.LatLonGridDescriptor.read(in_filename, latVarName='lat', lonVarName='lon')

out_filename = f"/users/pvankatw/research/ise/AIS_sectors_8km.nc"
outDescriptor = pyremap.get_polar_descriptor_from_file(out_filename, projection='antarctic')

# %%
remapper = pyremap.Remapper(inDescriptor, outDescriptor, mappingFileName='map.nc')

# %%
remapper.build_mapping_file(method='conservative')
# Out:
# /tmp/ipykernel_2791856/1299603666.py:1: DeprecationWarning: build_mapping_file() is deprecated.  Use esmf_build_map() or mbtempest_build_map() instead
#   remapper.build_mapping_file(method='conservative')
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 remapper.build_mapping_file(method='conservative')
#
# File ~/research/ise/.venv/lib/python3.12/site-packages/pyremap/remapper.py:235, in Remapper.build_mapping_file(self, method, additionalArgs, logger, mpiTasks, tempdir, esmf_path, esmf_parallel_exec, extrap_method, include_logs, expandDist, expandFactor)
#     228 # Authors
#     229 # -------
#     230 # Xylar Asay-Davis
#     232 warn('build_mapping_file() is deprecated.  Use esmf_build_map() or '
#     233      'mbtempest_build_map() instead', DeprecationWarning, stacklevel=2)
# --> 235 self._esmf_build_map(method=method, logger=logger, mpi_tasks=mpiTasks,
#     236                      tempdir=tempdir, parallel_exec=esmf_parallel_exec,
#     237                      include_logs=include_logs,
#     238                      expand_dist=expandDist,
#     239                      expand_factor=expandFactor,
#     240                      additional_args=additionalArgs,
#     241                      esmf_path=esmf_path,
#     242                      extrap_method=extrap_method)
#
# File ~/research/ise/.venv/lib/python3.12/site-packages/pyremap/remapper.py:721, in Remapper._esmf_build_map(self, method, logger, mpi_tasks, tempdir, parallel_exec, include_logs, expand_dist, expand_factor, additional_args, esmf_path, extrap_method)
#     717     return
#     719 self._validate_descriptors(method, expand_factor, expand_dist)
# --> 721 rwg_path = self._get_rwg_path(esmf_path)
#     723 # Write source and destination SCRIP files in temporary locations
#     724 if tempdir is None:
#
# File ~/research/ise/.venv/lib/python3.12/site-packages/pyremap/remapper.py:820, in Remapper._get_rwg_path(self, esmf_path)
#     817     rwg_path = which('ESMF_RegridWeightGen')
#     819     if rwg_path is None:
# --> 820         raise OSError('ESMF_RegridWeightGen not found. Make sure esmf '
#     821                       'package is installed: \n'
#     822                       'conda install esmf\n'
#     823                       'Note: this presumes use of the conda-forge '
#     824                       'channel.')
#     825 return rwg_path
#
# OSError: ESMF_RegridWeightGen not found. Make sure esmf package is installed:
# conda install esmf
# Note: this presumes use of the conda-forge channel.
